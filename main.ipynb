# %%
import json
import pandas as pd
from pathlib import Path

# %%
data = pd.read_csv(Path('Materials/MeteoBlue/dataexport_20210401T195405_hi-res.csv'))

# %%
data.head(9)
# Out:
#       location                   O.R. Tambo International Airport  \
# 0          lat                                          -26.14984
# 1          lon                                           28.27415
# 2          asl                                           1629.447
# 3     variable                                        Temperature
# 4         unit                                                 °C
# 5        level                            2 m elevation corrected
# 6   resolution                                             hourly
# 7  aggregation                                               None
# 8    timestamp  O.R. Tambo International Airport Temperature [...
#
#                                    Frankfurt am Main  \
# 0                                           50.11647
# 1                                            8.69360
# 2                                            119.513
# 3                                        Temperature
# ...

# %%
tempdata = data[9:]

# %%
df["Date"] = pd.to_datetime(df["Date"]).dt.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-45e7fa88a74f> in <module>
# ----> 1 df["Date"] = pd.to_datetime(df["Date"]).dt.strftime('%Y-%m-%d')
#
# NameError: name 'df' is not defined
